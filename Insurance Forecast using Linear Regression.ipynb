# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

data = pd.read_csv(r'C:\Users\DAMILOLA\Desktop\Ugo\Practice ML\ML Datasets\Medical Cost Personal Datasets (Insurance Forecast by using Linear Regression)\Data\mxl_ex.csv')
print(data.shape)
data.head()

# %% [markdown]
# # Check to see if 'age' is a strong influencer of the 'charges'

# %%
X = data['age'].values
Y = data['charges'].values

# %%
# mean of X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of observations
m = len(X)

# Using the formula to calculate b1 and b0
numer = 0 
denom = 0

for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# Print coefficients (m and c respectively - y = mx + c)
print(b1, b0)

# %%
# Plotting values and Regression line

max_x = np.max(X)
min_x = np.min(X)

# Calculating line values x and y 
x = np.linspace(min_x, max_x, 100)
y = b0 + (b1 * x)

# Plotting line
plt.plot(x, y, color='#58b970', label='Regression Line')

# Plotting scatter plot
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()

# %%
ss_t = 0 
ss_r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2 
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Cannot use Rank 1 matrix in scikit learn
X = X.reshape((m, 1))

# Creating Model
reg = LinearRegression()

# Fitting training data
reg = reg.fit(X, Y)

# Y Prediction
Y_pred = reg.predict(X)

# Calculating R2 score
r2_score = reg.score(X, Y)
print(r2_score)

# %% [markdown]
# ##### The above value of R-square means that 'Age' is not a strong influencer of the 'Charges'

# %% [markdown]
# # Check to see if 'body mass index' is a strong influencer of the 'charges'

# %%
X = data['bmi'].values
Y = data['charges'].values

# %%
# mean of X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of observations
m = len(X)

# Using the formula to calculate b1 and b0
numer = 0 
denom = 0

for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# Print coefficients (m and c respectively - y = mx + c)
print(b1, b0)
# Out:
# 477.078335772 -805.545165192

# %%
# Plotting values and Regression line

max_x = np.max(X)
min_x = np.min(X)

# Calculating line values x and y 
x = np.linspace(min_x, max_x, 100)
y = b0 + (b1 * x)

# Plotting line
plt.plot(x, y, color='#58b970', label='Regression Line')

# Plotting scatter plot
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()

# %%
ss_t = 0 
ss_r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2 
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.0510069035412

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Cannot use Rank 1 matrix in scikit learn
X = X.reshape((m, 1))

# Creating Model
reg = LinearRegression()

# Fitting training data
reg = reg.fit(X, Y)

# Y Prediction
Y_pred = reg.predict(X)

# Calculating R2 score
r2_score = reg.score(X, Y)
print(r2_score)

# %% [markdown]
# ##### The above value of R-square means that 'bmi' is not a strong influencer of the 'Charges'

# %% [markdown]
# # Check to see if 'having children' is a strong influencer of the 'charges'

# %%
X = data['children'].values
Y = data['charges'].values

# %%
# mean of X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of observations
m = len(X)

# Using the formula to calculate b1 and b0
numer = 0 
denom = 0

for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# Print coefficients (m and c respectively - y = mx + c)
print(b1, b0)
# Out:
# 792.704341912 13072.5809502

# %%
# Plotting values and Regression line

max_x = np.max(X)
min_x = np.min(X)

# Calculating line values x and y 
x = np.linspace(min_x, max_x, 100)
y = b0 + (b1 * x)

# Plotting line
plt.plot(x, y, color='#58b970', label='Regression Line')

# Plotting scatter plot
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()

# %%
ss_t = 0 
ss_r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2 
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.005549718823

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Cannot use Rank 1 matrix in scikit learn
X = X.reshape((m, 1))

# Creating Model
reg = LinearRegression()

# Fitting training data
reg = reg.fit(X, Y)

# Y Prediction
Y_pred = reg.predict(X)

# Calculating R2 score
r2_score = reg.score(X, Y)
print(r2_score)

# %% [markdown]
# ##### The above value of R-square means that 'children' is not a strong influencer of the 'Charges'

# %% [markdown]
# # Check to see if 'smoker' is a strong influencer of the 'charges'

# %%
X = data['smoker'].values
Y = data['charges'].values

# %%
# mean of X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of observations
m = len(X)

# Using the formula to calculate b1 and b0
numer = 0 
denom = 0

for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

# Print coefficients (m and c respectively - y = mx + c)
print(b1, b0)
# Out:
# 24954.801244 8087.20473128

# %%
# Plotting values and Regression line

max_x = np.max(X)
min_x = np.min(X)

# Calculating line values x and y 
x = np.linspace(min_x, max_x, 100)
y = b0 + (b1 * x)

# Plotting line
plt.plot(x, y, color='#58b970', label='Regression Line')

# Plotting scatter plot
plt.scatter(X, Y, c='#ef5423', label='Scatter Plot')

plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()

# %%
ss_t = 0 
ss_r = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2 
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.666801817695

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Cannot use Rank 1 matrix in scikit learn
X = X.reshape((m, 1))

# Creating Model
reg = LinearRegression()

# Fitting training data
reg = reg.fit(X, Y)

# Y Prediction
Y_pred = reg.predict(X)

# Calculating R2 score
r2_score = reg.score(X, Y)
print(r2_score)

# %% [markdown]
# ##### The above value of R-square means that 'children' is a strong influencer of the 'Charges'

# %% [markdown]
# # Inference:
# # This means that the strongest factor that influences the Individual medical costs billed by health insurance is if the individual is a smoker or not
